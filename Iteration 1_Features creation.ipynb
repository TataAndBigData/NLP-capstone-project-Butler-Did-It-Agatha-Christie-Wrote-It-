# %% [markdown]
# # Features Engineering

# %% [markdown]
# My further feature engineering and EDA aim to find the patterns representing individual manner of writting specific for each of the selected 40 authors.
#
# My hypothesis is that since these authors belong to the different generation, populational and gender groups, they are likely to have detectable style of writting and/or vocabulary, that the model will be able to identify and use for labelling the paragraphs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from nltk.tag import pos_tag
from nltk.tokenize import WordPunctTokenizer
from nltk.tag import StanfordPOSTagger

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer

# %%
fin_lines = pd.read_csv('/Users/eiwi/GA_stuff/GA_lessons/DSI11-lessons/projects/project-capstone/For GitHub/final_lines_df_iteration_1_sent.csv')

# %%
fin_lines.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  book_author  \
# 0           0             0  Grant Allen
# 1           1             1  Grant Allen
# 2           2             2  Grant Allen
# 3           3             3  Grant Allen
# 4           4             4  Grant Allen
#
#                                            book_line  len_line    neg    neu  \
# 0   often happens, chance stepped in at the very ...       307  0.058  0.908
# 1   led him out to the door.  policeman, in obedi...       434  0.231  0.669
# 2  “.   has nothing at all to do with the point, ...       303  0.051  0.949
# 3   small building at the foot of the , now in co...       317  0.039  0.926
# 4   fancy pleased him, and he talked awhile with ...       499  0.000  0.896
#
#      pos  compound  objectivity  pos_vs_neg
# 0  0.034   -0.3400        0.908      -0.024
# 1  0.100   -0.9233        0.669      -0.131
# 2  0.000   -0.4588        0.949      -0.051
# 3  0.035   -0.0550        0.926      -0.004
# 4  0.104    0.8387        0.896       0.104

# %% [markdown]
# # Step 1. Sentiment analysis

# %% [markdown]
# The sentiment analysis has been performed with Vader Tokenizer. Since it requires different kernel, this has been performed in the different notebook with the following code:

# %% [raw]
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# vader = SentimentIntensityAnalyzer()
#
# from sklearn.feature_extraction import DictVectorizer
# dvec = DictVectorizer()

# %% [raw]
# neg_list = []
# neu_list = []
# pos_list = []
# compound_list = []
#
# for i in range(len(fin_lines.line)):
#     score = vader.polarity_scores(fin_lines.line[i])
#     neg_list.append(score['neg'])
#     neu_list.append(score['neu'])
#     pos_list.append(score['pos'])
#     compound_list.append(score['compound'])

# %% [raw]
# fin_lines['neg'] = neg_list
# fin_lines['neu'] = neu_list
# fin_lines['pos'] = pos_list
# fin_lines['compound'] = compound_list
#
# fin_lines['objectivity'] = 1 - (fin_lines['pos'] + fin_lines['neg'])
# fin_lines['pos_vs_neg'] = fin_lines['pos'] - fin_lines['neg']

# %% [markdown]
# The results have been saved into a new DataFrame 'final_lines_df_iteration_1_sent.csv', which is used for the further feature engineering.
#
# The sentiment analysis features as I assume should track author's personal level of 'gruesomeness'.
# The illustration below demonstrates that there are several authors, for whom ratios between 'positive' and 'negative' words are quite different from average score.

# %%
fin_lines.groupby('book_author')['pos_vs_neg'].mean().plot(kind = 'barh', figsize = (10,8))

# %% [markdown]
# # Step 2. Parts of speech tagging
#
# In order to limit the number of features I will combine standard NLTK tags into bigger groups as follows:
#
# *TAG MEANING*
#
# - ADJ	adjective
# - ADV	adverb
# - CONJ	conjunction
# - DET	determiner, article
# - NOUN	noun
# - NUM	numeral
# - PRT	particle
# - PRON	pronoun
# - VERB	verb
# - PUNCT punctuation marks
# - other
#
# Initially, I have been using standard NLTK pos_tag functionality, however, it had difficulties identifying the exclamation and question marks, taht in my opinion could refer to author's emotionality and potentially be an important feature, so I moved to StanfordPOSTagger. However, it still had the same issue.

# %%
# Adding new columns for the future features into DF

list_of_new_cols = ['ADJ','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB', 'Commas', 'Full_stops', 
                    'Dashes', 'Brackets', 'Exclamation', 'Question', 'Punct','Foreign','Other']

for new_col in list_of_new_cols:
    fin_lines.insert(len(fin_lines.columns), new_col, 0)

# %%
# Parts of speech (POS) tags will be added via standard NLTK WordPunctTokenizer and StanfordPOSTagger.

tok = WordPunctTokenizer()

# %%
# StanfordPOSTagger

jar = '/Users/eiwi/Downloads/stanford-postagger-full-2018-10-16/stanford-postagger.jar'
model = '/Users/eiwi/Downloads/stanford-postagger-full-2018-10-16/models/english-bidirectional-distsim.tagger'

st_tagger = StanfordPOSTagger(model, jar, encoding='utf8')

# %%
text = fin_lines.book_line[115]
text
# Out:
# ', very well, you shall see! I said, buttoning up my coat resolutely and rising to my feet.  shall see that I will find out everything in once. I, a stranger in , who love the oceans and the forests better than the cities, I, who know only the secrets of , behold, I will solve you this mystery of humanity.'

# %%
lst_words = []
lst_pos_tags = []
lst_st_tags = []

# POS tagging with pos_tag 

for i,j in pos_tag(tok.tokenize(text)):
    lst_words.append(i)
    lst_pos_tags.append(j)
    
# POS tagging with pos_tag 

for i,j in st_tagger.tag(tok.tokenize(text)):
    lst_st_tags.append(j)
    
    
compare_pos_st_df = pd.DataFrame()
compare_pos_st_df['word'] = lst_words
compare_pos_st_df['pos_tag'] = lst_pos_tags
compare_pos_st_df['stanford_tag'] = lst_st_tags

# %% [markdown]
# However, it still had the same issue: StanfordPOSTagger had disagreement with pos_tag, but has not identified punctuation marks correctly either.

# %%
compare_pos_st_df.head(15)
# Out:
#          word pos_tag stanford_tag
# 0           ,       ,            ,
# 1        very      RB           RB
# 2        well      RB           RB
# 3           ,       ,            ,
# 4         you     PRP          PRP
# 5       shall      MD           MD
# 6         see      VB           VB
# 7           !       .            .
# 8           I     PRP          PRP
# 9        said     VBD          VBD
# 10          ,       ,            ,
# 11  buttoning     VBG          VBG
# 12         up      RP           RP
# 13         my    PRP$         PRP$
# 14       coat      NN           NN

# %%
compare_pos_st_df.tail(15)
# Out:
#         word pos_tag stanford_tag
# 56       the      DT           DT
# 57   secrets     NNS          NNS
# 58        of      IN           IN
# 59         ,       ,            ,
# 60    behold      NN           RB
# 61         ,       ,            ,
# 62         I     PRP          PRP
# 63      will      MD           MD
# 64     solve      VB           VB
# 65       you     PRP          PRP
# 66      this      DT           DT
# 67   mystery      NN           NN
# 68        of      IN           IN
# 69  humanity      NN           NN
# 70         .       .            .

# %% [markdown]
# Consequently, I decided to use NLTK for words' POS-tagging and calculating the whole amount of punctuation symbols in the paragraph, but also to write a custom function and determine whether the author uses certain symbols.

# %%
list_of_symbols = ['RB', 'RBR', 'RBS', 'WRB', 'JJ', 'JJR', 'JJS', 'CC', 'IN', 'DT', 'PDT', 'TO', 'NN', 'NNP', 'NNPS','NNS', 
  'RP', 'WDT', 'WP', 'WP$', 'PRP', 'PRP$', 'VB','VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'MD', 'EX', 'FW', 'CD',
  "$", "'", "(", "[", "{", ")", "] ", "}", ",", "-", "--", ".", "?", "!", ":", ";", "`",  "``",  "LS", "POS",
   'SYM', 'UH']
    
for line_number in range(len(fin_lines.book_line)):
    tags = dict(pos_tag(tok.tokenize(fin_lines.book_line[line_number])))
    for value in list_of_symbols:
        val_count = list(tags.values()).count(value)
        
        if value in ['RB', 'RBR', 'RBS', 'WRB']:
            fin_lines.ADV[line_number]  += val_count
            
        if value in ['JJ', 'JJR', 'JJS']:
            fin_lines.ADJ[line_number] += val_count  
           
        if value in ['CC', 'IN']:
            fin_lines.CONJ[line_number] += val_count 
        
        if value in ['DT', 'PDT', 'TO']:
            fin_lines.DET[line_number] += val_count 
            
        if value in ['NN', 'NNP', 'NNPS','NNS']:
            fin_lines.NOUN[line_number] += val_count
            
        if value in ['CD']:
            fin_lines.NUM[line_number] += val_count

        if value in ['RP']:
            fin_lines.PRT[line_number]  += val_count
 
        if value in ['WDT', 'WP', 'WP$', 'PRP', 'PRP$']:
            fin_lines.PRON[line_number] += val_count
            
        if value in ['VB','VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'MD', 'EX']:
            fin_lines.VERB[line_number] += val_count
            
        if value in ["$", "'", "(", "[", "{", ")", "] ", "}", ",", "-", "--", ".", "?", "!", ":", ";", "`",  "``"]:
            fin_lines.Punct[line_number]  += val_count
            
        if value in ['FW']:
            fin_lines.Foreign[line_number] += val_count
            
        if value in["LS", "POS", 'SYM', 'UH']:
            fin_lines.Other[line_number]  += val_count
# Out:
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Custom function

def count_punct(my_series):
    for line_number in range(len(my_series)):
        
        if '.' in my_series[line_number]:
            val_count = my_series[line_number].count(',')
            fin_lines.Full_stops[line_number]  += val_count
        
        if ',' in my_series[line_number]:
            val_count = my_series[line_number].count(',')
            fin_lines.Commas[line_number]  += val_count
            
        if ('!' in my_series[line_number]) or ('!!!' in my_series[line_number]):
            val_count = my_series[line_number].count(',')
            fin_lines.Exclamation[line_number]  += val_count
            
        if ('?' in my_series[line_number]) or ('?!' in my_series[line_number]):
            val_count = my_series[line_number].count(',')
            fin_lines.Question[line_number]  += val_count
            
        if ('(' in my_series[line_number]) and (')' in my_series[line_number]):
            val_count = my_series[line_number].count(',')
            fin_lines.Brackets[line_number]  += val_count
            
        if ('-' in my_series[line_number]) or ('--' in my_series[line_number]) or ('--' in my_series[line_number]):
            val_count = my_series[line_number].count(',')
            fin_lines.Dashes[line_number]  += val_count
            
count_punct(fin_lines.book_line)
# Out:
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fin_lines.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'], inplace = True)
fin_lines.reset_index(drop = True, inplace = True)

# %%
fin_lines.describe()
# Out:
#           len_line          neg          neu          pos     compound  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean    414.917188     0.076873     0.832306     0.090813     0.091026
# std      83.969998     0.064184     0.085503     0.064655     0.636811
# min     300.000000     0.000000     0.504000     0.000000    -0.990700
# 25%     343.000000     0.029000     0.776000     0.043750    -0.541400
# 50%     400.000000     0.065000     0.839000     0.080000     0.197450
# 75%     480.000000     0.114000     0.895000     0.128000     0.700300
# max     600.000000     0.443000     1.000000     0.446000     0.990900
#
#        objectivity   pos_vs_neg          ADJ          ADV         CONJ  ...  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000  ...
# mean      0.832315     0.013940     5.515000     4.400313     8.144687  ...
# std       0.085500     0.096382     2.644113     2.352375     2.223522  ...
# min       0.504000    -0.390000     0.000000     0.000000     1.000000  ...
# 25%       0.776000    -0.048000     4.000000     3.000000     7.000000  ...
# 50%       0.839000     0.014000     5.000000     4.000000     8.000000  ...
# 75%       0.895000     0.075000     7.000000     6.000000    10.000000  ...
# max       1.000000     0.440000    21.000000    17.000000    16.000000  ...
#
#               VERB       Commas   Full_stops       Dashes     Brackets  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean     13.983438     5.401562     5.384688     2.196875     0.204063
# std       4.048940     2.909438     2.916974     3.371356     1.244902
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%      11.000000     3.000000     3.000000     0.000000     0.000000
# 50%      14.000000     5.000000     5.000000     0.000000     0.000000
# 75%      17.000000     7.000000     7.000000     4.000000     0.000000
# max      32.000000    21.000000    21.000000    21.000000    19.000000
#
#        Exclamation     Question        Punct      Foreign        Other
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean      0.721562     0.845938     2.989063     0.026250     0.040313
# std       2.241926     2.325568     0.957786     0.180128     0.212018
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     0.000000     2.000000     0.000000     0.000000
# 50%       0.000000     0.000000     3.000000     0.000000     0.000000
# 75%       0.000000     0.000000     4.000000     0.000000     0.000000
# max      19.000000    19.000000     7.000000     3.000000     3.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# These features are designed to pick up author's individual style: e.g. the tendency to use more verbs or nouns, 'favourite' punctuation marks, etc.
#
# The table below proves that some authors stand out of the common pattern (within the used sample): as we can see, Mignon G.Eberhart tends to use more adverbs than others or that Grant Allen is an absolute leader of using exclamation marks.

# %%
pos_author = fin_lines.groupby('book_author')['ADJ','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB', 'Commas', 'Full_stops', 
                    'Dashes', 'Brackets', 'Exclamation', 'Question', 'Punct','Foreign','Other'].mean()
# Out:
# /Users/eiwi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
def highlight_max(s): # highlights the maximum in a column
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
pos_author.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_527e13c6_7da5_11ea_887e_acde48001122row2_col3 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row7_col16 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row7_col17 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row8_col12 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row12_col0 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row13_col2 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row13_col6 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row13_col7 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row18_col13 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row19_col8 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row28_col5 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row28_col9 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row28_col10 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row28_col11 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row28_col14 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row28_col15 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row29_col4 {
#             background-color:  yellow;
#         }    #T_527e13c6_7da5_11ea_887e_acde48001122row32_col1 {
#             background-color:  yellow;
#         }</style><table id="T_527e13c6_7da5_11ea_887e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ADJ</th>        <th class="col_heading level0 col1" >ADV</th>        <th class="col_heading level0 col2" >CONJ</th>        <th class="col_heading level0 col3" >DET</th>        <th class="col_heading level0 col4" >NOUN</th>        <th class="col_heading level0 col5" >NUM</th>        <th class="col_heading level0 col6" >PRT</th>        <th class="col_heading level0 col7" >PRON</th>        <th class="col_heading level0 col8" >VERB</th>        <th class="col_heading level0 col9" >Commas</th>        <th class="col_heading level0 col10" >Full_stops</th>        <th class="col_heading level0 col11" >Dashes</th>        <th class="col_heading level0 col12" >Brackets</th>        <th class="col_heading level0 col13" >Exclamation</th>        <th class="col_heading level0 col14" >Question</th>        <th class="col_heading level0 col15" >Punct</th>        <th class="col_heading level0 col16" >Foreign</th>        <th class="col_heading level0 col17" >Other</th>    </tr>    <tr>        <th class="index_name level0" >book_author</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_527e13c6_7da5_11ea_887e_acde48001122level0_row0" class="row_heading level0 row0" >Agatha Christie</th>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col0" class="data row0 col0" >5.512500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col1" class="data row0 col1" >4.825000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col2" class="data row0 col2" >7.287500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col3" class="data row0 col3" >3.962500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col4" class="data row0 col4" >14.462500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col5" class="data row0 col5" >0.425000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col6" class="data row0 col6" >0.350000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col7" class="data row0 col7" >5.062500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col8" class="data row0 col8" >14.175000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col9" class="data row0 col9" >4.675000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col10" class="data row0 col10" >4.625000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col11" class="data row0 col11" >1.387500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col12" class="data row0 col12" >0.087500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col13" class="data row0 col13" >0.850000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col14" class="data row0 col14" >1.050000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col15" class="data row0 col15" >2.662500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col16" class="data row0 col16" >0.050000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row0_col17" class="data row0 col17" >0.062500</td>
#             </tr>
#             <tr>
#                         <th id="T_527e13c6_7da5_11ea_887e_acde48001122level0_row1" class="row_heading level0 row1" >Anna Katharine Green</th>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col0" class="data row1 col0" >5.462500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col1" class="data row1 col1" >4.062500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col2" class="data row1 col2" >8.412500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col3" class="data row1 col3" >4.837500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col4" class="data row1 col4" >14.600000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col5" class="data row1 col5" >0.337500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col6" class="data row1 col6" >0.312500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col7" class="data row1 col7" >6.000000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col8" class="data row1 col8" >14.787500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col9" class="data row1 col9" >4.975000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col10" class="data row1 col10" >4.837500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col11" class="data row1 col11" >1.500000</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col12" class="data row1 col12" >0.087500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col13" class="data row1 col13" >0.837500</td>
#                         <td id="T_527e13c6_7da5_11ea_887e_acde48001122row1_col14" class="data row1 col14" >0.737500</td>

# %% [markdown]
# # Step 3. Stemming and Tokens Counting
#
# At this point I am going to reduce the number of used tokens by using Porter Stemmer and count the frequency of tehse tokens use with TfidfVectorizer.

# %%
porter=PorterStemmer()

# %%
def stemSentence(line):
    token_words=word_tokenize(line)
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)

stem_list = []

for line in fin_lines.book_line:
    new_line = stemSentence(line)
    stem_list.append(new_line)

# %%
fin_lines['book_line'] = stem_list

# %%
fin_lines.book_line.head()
# Out:
# 0    often happen , chanc step in at the veri nick ...
# 1    led him out to the door . policeman , in obedi...
# 2    “ . ha noth at all to do with the point , one ...
# 3    small build at the foot of the , now in cours ...
# 4    fanci pleas him , and he talk awhil with the c...
# Name: book_line, dtype: object

# %% [markdown]
# Next I would like to extract most representative word features, that may point out authors' "favourite" words and help to identify their writing. As suggests the following graph, this assumption seems to be realistic and worth trying.

# %%
# I will use CountVectorizer to illustrate the difference in frequency of using the same words by different authors

cvec = CountVectorizer(token_pattern='\w+', stop_words='english', min_df=0.003)
cvec.fit(fin_lines['book_line'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=0.003,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='\\w+', tokenizer=None,
#                 vocabulary=None)

# %%
document_matrix = cvec.transform(fin_lines['book_line'])
document_matrix
# Out:
# <3200x1952 sparse matrix of type '<class 'numpy.int64'>'
# 	with 80286 stored elements in Compressed Sparse Row format>

# %%
cvec_df = pd.DataFrame(document_matrix.toarray(),
                  columns=cvec.get_feature_names())

cvec_df = cvec_df.transpose().sort_values(0, ascending=False).transpose()

# %%
most_popular_50 = cvec_df.iloc[:, :50]
most_popular_50.insert(loc = 0, column ='book_author', value = fin_lines['book_author'])

# %%
most_popular_50.groupby('book_author').sum().style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_55e88e38_7da5_11ea_887e_acde48001122row0_col14 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row0_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row0_col48 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row1_col42 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row1_col45 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row2_col17 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row2_col18 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row2_col20 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row2_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row2_col31 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row2_col40 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row4_col7 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row5_col32 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row7_col38 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row7_col40 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row7_col46 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row9_col24 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row9_col38 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row9_col39 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row9_col49 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row10_col21 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row10_col22 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row11_col7 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row11_col40 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row12_col14 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row12_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row12_col28 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row12_col35 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row13_col1 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row13_col3 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row13_col26 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row14_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row15_col23 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row15_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row15_col34 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row16_col25 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row17_col8 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row17_col16 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row17_col30 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row18_col5 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row18_col11 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row18_col12 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row18_col32 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row19_col40 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row20_col38 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row20_col46 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row21_col0 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row21_col6 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row21_col13 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row21_col15 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row21_col32 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row21_col49 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row22_col44 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row23_col41 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row24_col8 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row25_col2 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row25_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row27_col4 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row27_col14 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row27_col27 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row27_col41 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row28_col2 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row28_col10 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row29_col31 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row29_col32 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row30_col29 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row30_col33 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row30_col34 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row30_col48 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row30_col49 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row32_col28 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row32_col34 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row34_col10 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row34_col34 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row36_col9 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_887e_acde48001122row36_col36 {
#             background-color:  yellow;
#         }    #T_55e88e38_7da5_11ea_8

# %% [markdown]
# The following graph shows that the authios use the same 20 most popular words differently: Nililas Blake and Matthew Phipps Shiel use the word 'night' more seldom than others, while Agatha Christie and Ernest Bramah mention 'time' a lot, Grant Allen (who has already been identified as a frequent user of exclamation marks) also uses word token 'very', and so on.
#
# However, this representation is based only on the word frequency, while the better approach would be to consider the number of the paragraphs containing these words too (TfIdf approach). This will allow not only to identify the frequently used words, but also evaluate how important a word is to a paragraph in a collection or corpus. Therefore, I will use TfidfVectorizer for the further feature engineering.

# %%
most_popular_50.groupby('book_author').sum().plot(kind = 'barh', figsize = (15,18), colormap = 'tab20')

# %%
# Counting

tvec = TfidfVectorizer(stop_words='english',  encoding='utf-8', 
                       lowercase=True, analyzer='word', 
                       ngram_range=(1, 3), min_df=0.003) # I only take 3% of all corpus to make the computations easier

# %%
tvec.fit(fin_lines['book_line'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=0.003, ngram_range=(1, 3), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
import numpy as np 

tdidf_df = pd.DataFrame(np.round(tvec.transform(fin_lines['book_line']).toarray(),3), 
                        columns = tvec.get_feature_names())

# %% [markdown]
# This gives me 190119 predictors representing n-grams of the level 1 to 3, most frequently used in the chosen paragraphs.

# %%
new_df = pd.concat([fin_lines, tdidf_df], join="outer", axis = 1)

# %%
new_df.to_csv(r'/Users/eiwi/GA_stuff/GA_lessons/DSI11-lessons/projects/project-capstone/For GitHub/df_40_authors_all_features_0003percent.csv', columns = new_df.columns)
